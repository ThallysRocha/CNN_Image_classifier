# %%
#Load libraries
import os
import numpy as np
import torch
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable
import torchvision
import pathlib
import matplotlib.pyplot as plt

# %%
import cv2
import imghdr

# %%
data_dir = 'data/train_data/'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
           # os.remove(image_path)

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
print(device)
# Out:
# cpu

# %% [markdown]
# Load Data

# %%
#Transforms
transformer=transforms.Compose([
    transforms.Resize((150,150)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5,0.5,0.5], # 0-1 to [-1,1] , formula (x-mean)/std
                        [0.5,0.5,0.5])
])

# %%
train_path = 'data/train_data/'
test_path = 'data/test_data/'

# %%
train_loader=DataLoader(
    torchvision.datasets.ImageFolder(train_path,transform=transformer),
    batch_size=128, shuffle=True
)
test_loader=DataLoader(
    torchvision.datasets.ImageFolder(test_path,transform=transformer),
    batch_size=16, shuffle=True
)

# %%
#categories
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
print(classes)
# Out:
# ['KanyeWest', 'TaylorSwift']

# %%
#CNN Network


class ConvNet(nn.Module):
    def __init__(self,num_classes=2):
        super(ConvNet,self).__init__()
        
        #Output size after convolution filter
        #((w-f+2P)/s) +1
        
        #Input shape= (256,3,150,150)
        
        self.conv1=nn.Conv2d(in_channels=3,out_channels=12,kernel_size=3,stride=1,padding=1)
        #Shape= (256,12,150,150)
        self.bn1=nn.BatchNorm2d(num_features=12)
        #Shape= (256,12,150,150)
        self.relu1=nn.ReLU()
        #Shape= (256,12,150,150)
        
        self.pool=nn.MaxPool2d(kernel_size=2)
        #Reduce the image size be factor 2
        #Shape= (256,12,75,75)
        
        
        self.conv2=nn.Conv2d(in_channels=12,out_channels=20,kernel_size=3,stride=1,padding=1)
        #Shape= (256,20,75,75)
        self.relu2=nn.ReLU()
        #Shape= (256,20,75,75)
        
        
        
        self.conv3=nn.Conv2d(in_channels=20,out_channels=32,kernel_size=3,stride=1,padding=1)
        #Shape= (256,32,75,75)
        self.bn3=nn.BatchNorm2d(num_features=32)
        #Shape= (256,32,75,75)
        self.relu3=nn.ReLU()
        #Shape= (256,32,75,75)
        
        
        self.fc=nn.Linear(in_features=75 * 75 * 32,out_features=num_classes)
        
        
        
        #Feed forwad function
        
    def forward(self,input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
            
        output=self.pool(output)
            
        output=self.conv2(output)
        output=self.relu2(output)
            
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)
            
            
            #Above output will be in matrix form, with shape (256,32,75,75)
            
        output=output.view(-1,32*75*75)
            
            
        output=self.fc(output)
        #print(output)
        return output

# %%
model=ConvNet(num_classes=2).to(device)

# %%
#Optmizer and loss function
optimizer=Adam(model.parameters(),lr=0.0001,weight_decay=0.0001)
loss_function=nn.CrossEntropyLoss()

# %%
num_epochs=30

# %%
# train_count=len(glob.glob(train_path+'/**/*.jpg'))
# test_count=len(glob.glob(test_path+'/**/*.jpg'))
train_count=len(glob.glob(train_path+'/**/*'))
test_count=len(glob.glob(test_path+'/**/*'))

# %%
print(train_count,test_count)
# Out:
# 912 107

# %%
def softmax(values):
 
    # Computing element wise exponential value
    exp_values = np.exp(values)
 
    # Computing sum of these values
    exp_values_sum = np.sum(exp_values)
 
    # Returing the softmax output.
    return exp_values/exp_values_sum

# %%
#Model training and saving best model

best_accuracy=0.0

for epoch in range(num_epochs):
    
    #Evaluation and training on training dataset
    model.train()
    train_accuracy=0.0
    train_loss=0.0
    
    for i, (images,labels) in enumerate(train_loader):
        
        if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())
            
        optimizer.zero_grad()
        
        outputs=model(images)
        #print(outputs)
        loss=loss_function(outputs,labels)
        loss.backward()
        optimizer.step()
        
        
        train_loss+= loss.cpu().data*images.size(0)
        _,prediction=torch.max(outputs.data,1)
        
        train_accuracy+=int(torch.sum(prediction==labels.data))
        
    train_accuracy=train_accuracy/train_count
    train_loss=train_loss/train_count
    
    
    # Evaluation on testing dataset
    model.eval()
    
    test_accuracy=0.0
    for i, (images,labels) in enumerate(test_loader):
        # print(i,labels.data, images.shape)
        if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())
            
        outputs=model(images)
        # print(np.max(outputs.data.numpy(),1))
        _,prediction=torch.max(outputs.data,1)
        values = np.apply_along_axis(softmax, 1, outputs.data.numpy())
        #print(values)
        #print(values[prediction!=labels.data],prediction != labels.data)
        test_accuracy+=int(torch.sum(prediction==labels.data))
        # print(prediction, labels.data)
        for j in range(len(prediction)):
            # print(f"Label: {labels.data} Prediction: {prediction} Values: {values}")
            if prediction[j] != labels.data[j]:
                # plt.imshow(images[j].cpu().numpy().transpose(1,2,0))
                # plt.show()
                print(f"Label: {classes[labels.data[j]]} Prediction: {classes[prediction[j]]} Values: {values[j]}")
    test_accuracy=test_accuracy/test_count
    
    
    print('Epoch: '+str(epoch)+' Train Loss: '+str(train_loss)+' Train Accuracy: '+str(train_accuracy)+' Test Accuracy: '+str(test_accuracy))
    
    #Save the best model
    if test_accuracy>best_accuracy:
        #torch.save(model.state_dict(),'best_checkpoint.model')
        best_accuracy=test_accuracy
# Out:
# Label: TaylorSwift Prediction: KanyeWest Values: [0.68749243 0.3125075 ]
# Label: KanyeWest Prediction: TaylorSwift Values: [1.7375287e-06 9.9999821e-01]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.95203507 0.04796489]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.55763865 0.4423613 ]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.00154972 0.9984503 ]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.8692002  0.13079979]
# Label: KanyeWest Prediction: TaylorSwift Values: [5.6463305e-09 1.0000000e+00]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.

# Label: KanyeWest Prediction: TaylorSwift Values: [1.9507284e-05 9.9998045e-01]
# Epoch: 24 Train Loss: tensor(0.0252) Train Accuracy: 0.9989035087719298 Test Accuracy: 0.8878504672897196
# Label: KanyeWest Prediction: TaylorSwift Values: [4.333519e-08 1.000000e+00]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.01655384 0.9834462 ]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.96281976 0.03718025]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9980672 0.0019328]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.04025104 0.959749  ]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.8210375 0.1789625]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.88561743 0.11438257]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.5730698  0.42693016]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.999987e-01 1.311111e-06]
# Label: KanyeWest Prediction: TaylorSwift Values: [2.9693882e-04 9.9970305e-01]
# Epoch: 25 Train Loss: tensor(0.0154) Train Accuracy: 0.9989035087719298 Test Accuracy: 0.9065420560747663
# Label: KanyeWest Prediction: TaylorSwift Values: [0.02497388 0.97502613]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.53849906 0.4615009 ]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.07907731 0.92092264]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.90844685 0.09155316]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9971823  0.00281768]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9970758e-01 2.9246561e-04]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9999875e-01 1.2785315e-06]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.98181534 0.01818462]
# Label: KanyeWest Prediction: TaylorSwift Values: [4.1523157e-04 9.9958479e-01]
# Label: KanyeWest Prediction: TaylorSwift Values: [5.169582e-05 9.999483e-01]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.0073645  0.99263555]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.00462416 0.9953759 ]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9227392  0.07726079]
# Epoch: 26 Train Loss: tensor(0.0083) Train Accuracy: 0.9978070175438597 Test Accuracy: 0.8785046728971962
# Label: KanyeWest Prediction: TaylorSwift Values: [0.05188473 0.9481153 ]
# Label: KanyeWest Prediction: TaylorSwift Values: [3.798017e-08 1.000000e+00]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9999857e-01 1.4178187e-06]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.01265709 0.98734295]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.96795005 0.03204992]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.0048013  0.99519867]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.67423195 0.32576802]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.5294082  0.47059178]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9999678e-01 3.2586952e-06]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.5952682  0.40473184]
# Label: KanyeWest Prediction: TaylorSwift Values: [4.3787892e-04 9.9956208e-01]
# Epoch: 27 Train Loss: tensor(0.0084) Train Accuracy: 0.9978070175438597 Test Accuracy: 0.897196261682243
# Label: TaylorSwift Prediction: KanyeWest Values: [0.7404221 0.2595779]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9969643e-01 3.0354108e-04]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.00767626 0.9923237 ]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.94921815 0.05078188]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9999982e-01 1.4081485e-07]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.18712592 0.81287414]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.99679106 0.00320893]
# Label: KanyeWest Prediction: TaylorSwift Values: [7.914881e-07 9.999992e-01]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.97619605 0.02380392]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9980736e-01 1.9265358e-04]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9585693  0.04143069]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9622136  0.03778637]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9047636  0.09523647]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.73731595 0.26268405]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.32257214 0.6774278 ]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9998242e-01 1.7570013e-05]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9707159 0.0292841]
# Epoch: 28 Train Loss: tensor(0.0142) Train Accuracy: 0.9978070175438597 Test Accuracy: 0.8411214953271028
# Label: TaylorSwift Prediction: KanyeWest Values: [0.96498144 0.03501852]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.7467968  0.25320324]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.6132667  0.38673332]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.36338744 0.63661253]
# Label: TaylorSwift Prediction: KanyeWest Values: [1.000000e+00 2.791512e-08]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9993753e-01 6.2452506e-05]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9986345e-01 1.3650529e-04]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.3647229 0.6352771]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.987467   0.01253302]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.94478947 0.05521052]
# Label: TaylorSwift Prediction: KanyeWest Values: [9.9999988e-01 5.4154775e-08]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.8612188  0.13878118]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9890256 0.0109744]
# Label: KanyeWest Prediction: TaylorSwift Values: [0.00968234 0.99031764]
# Label: KanyeWest Prediction: TaylorSwift Values: [1.2708311e-06 9.9999869e-01]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.6813798 0.3186202]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.9619122 0.0380878]
# Label: TaylorSwift Prediction: KanyeWest Values: [0.99268174 0.00731824]
# Epoch: 29 Train Loss: tensor(0.0133) Train Accuracy: 0.9978070175438597 Test Accuracy: 0.8317757009345794

# %%
# plt.imshow(img.permute(1,2,0))
#    plt.show()
#    print(f"Label: {label}")
